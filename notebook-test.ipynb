# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-0.1.17-py3-none-any.whl.metadata (13 kB)
# Collecting PyYAML>=5.3 (from langchain)
#   Using cached PyYAML-6.0.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Using cached SQLAlchemy-2.0.29-cp312-cp312-macosx_10_9_x86_64.whl.metadata (9.6 kB)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain)
#   Using cached aiohttp-3.9.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (7.5 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain)
#   Using cached dataclasses_json-0.6.5-py3-none-any.whl.metadata (25 kB)
# Collecting jsonpatch<2.0,>=1.33 (from langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-community<0.1,>=0.0.36 (from langchain)
#   Using cached langchain_community-0.0.36-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.48 (from langchain)
#   Using cached langchain_core-0.1.48-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain)
#   Using cached langchain_text_splitters-0.0.1-py3-none-any.whl.metadata (2.0 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain)
#   Using cached langsmith-0.1.52-py3-none-any.whl.metadata (13 kB)
# Collecting numpy<2,>=1 (from langchain)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# Collecting pydantic<3,>=1 (from langchain)
#   Using cached pydantic-2.7.1-py3-none-any.whl.metadata (107 kB)
# Collecting requests<3,>=2 (from langchain)
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain)
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached frozenlist-1.4.1-cp312-cp312-macosx_10_9_x86_64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached multidict-6.0.5-cp312-cp312-macosx_10_9_x86_64.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0.0,>=3.8.3->langchain)
#   Using cached yarl-1.9.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (31 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached marshmallow-3.21.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain)
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.2.0,>=0.1.48->langchain)
#   Using cached packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain)
#   Using cached orjson-3.10.2-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1->langchain)
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.18.2 (from pydantic<3,>=1->langchain)
#   Using cached pydantic_core-2.18.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.5 kB)
# Collecting typing-extensions>=4.6.1 (from pydantic<3,>=1->langchain)
#   Using cached typing_extensions-4.11.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3,>=2->langchain)
#   Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2->langchain)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Using cached urllib3-2.2.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2->langchain)
#   Using cached certifi-2024.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting greenlet!=0.4.17 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.0.3-cp312-cp312-macosx_11_0_universal2.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain-0.1.17-py3-none-any.whl (867 kB)
# Using cached aiohttp-3.9.5-cp312-cp312-macosx_10_9_x86_64.whl (395 kB)
# Using cached dataclasses_json-0.6.5-py3-none-any.whl (28 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langchain_community-0.0.36-py3-none-any.whl (2.0 MB)
# Using cached langchain_core-0.1.48-py3-none-any.whl (302 kB)
# Using cached langchain_text_splitters-0.0.1-py3-none-any.whl (21 kB)
# Using cached langsmith-0.1.52-py3-none-any.whl (116 kB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
# Using cached pydantic-2.7.1-py3-none-any.whl (409 kB)
# Using cached pydantic_core-2.18.2-cp312-cp312-macosx_10_12_x86_64.whl (1.9 MB)
# Using cached PyYAML-6.0.1-cp312-cp312-macosx_10_9_x86_64.whl (178 kB)
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Using cached SQLAlchemy-2.0.29-cp312-cp312-macosx_10_9_x86_64.whl (2.1 MB)
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Using cached certifi-2024.2.2-py3-none-any.whl (163 kB)
# Using cached charset_normalizer-3.3.2-cp312-cp312-macosx_10_9_x86_64.whl (122 kB)
# Using cached frozenlist-1.4.1-cp312-cp312-macosx_10_9_x86_64.whl (53 kB)
# Using cached greenlet-3.0.3-cp312-cp312-macosx_11_0_universal2.whl (273 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Using cached marshmallow-3.21.1-py3-none-any.whl (49 kB)
# Using cached multidict-6.0.5-cp312-cp312-macosx_10_9_x86_64.whl (29 kB)
# Using cached orjson-3.10.2-cp312-cp312-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (253 kB)
# Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Using cached typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached urllib3-2.2.1-py3-none-any.whl (121 kB)
# Using cached yarl-1.9.4-cp312-cp312-macosx_10_9_x86_64.whl (81 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: urllib3, typing-extensions, tenacity, PyYAML, packaging, orjson, numpy, mypy-extensions, multidict, jsonpointer, idna, greenlet, frozenlist, charset-normalizer, certifi, attrs, annotated-types, yarl, typing-inspect, SQLAlchemy, requests, pydantic-core, marshmallow, jsonpatch, aiosignal, pydantic, dataclasses-json, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed PyYAML-6.0.1 SQLAlchemy-2.0.29 aiohttp-3.9.5 aiosignal-1.3.1 annotated-types-0.6.0 attrs-23.2.0 certifi-2024.2.2 charset-normalizer-3.3.2 dataclasses-json-0.6.5 frozenlist-1.4.1 greenlet-3.0.3 idna-3.7 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.17 langchain-community-0.0.36 langchain-core-0.1.48 langchain-text-splitters-0.0.1 langsmith-0.1.52 marshmallow-3.21.1 multidict-6.0.5 mypy-extensions-1.0.0 numpy-1.26.4 orjson-3.10.2 packaging-23.2 pydantic-2.7.1 pydantic-core-2.18.2 requests-2.31.0 tenacity-8.2.3 typing-extensions-4.11.0 typing-inspect-0.9.0 urllib3-2.2.1 yarl-1.9.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "langserve[all]"
# Out:
# Collecting langserve[all]
#   Using cached langserve-0.1.1-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1,>=0.90.1 (from langserve[all])
#   Using cached fastapi-0.110.3-py3-none-any.whl.metadata (24 kB)
# Collecting httpx>=0.23.0 (from langserve[all])
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.0 in ./venv/lib/python3.12/site-packages (from langserve[all]) (0.1.48)
# Requirement already satisfied: orjson>=2 in ./venv/lib/python3.12/site-packages (from langserve[all]) (3.10.2)
# Requirement already satisfied: pydantic>=1 in ./venv/lib/python3.12/site-packages (from langserve[all]) (2.7.1)
# Collecting sse-starlette<2.0.0,>=1.3.0 (from langserve[all])
#   Using cached sse_starlette-1.8.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<1,>=0.90.1->langserve[all])
#   Using cached starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./venv/lib/python3.12/site-packages (from fastapi<1,>=0.90.1->langserve[all]) (4.11.0)
# Collecting anyio (from httpx>=0.23.0->langserve[all])
#   Using cached anyio-4.3.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: certifi in ./venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve[all]) (2024.2.2)
# Collecting httpcore==1.* (from httpx>=0.23.0->langserve[all])
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in ./venv/lib/python3.12/site-packages (from httpx>=0.23.0->langserve[all]) (3.7)
# Collecting sniffio (from httpx>=0.23.0->langserve[all])
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.23.0->langserve[all])
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: PyYAML>=5.3 in ./venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.0->langserve[all]) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.0->langserve[all]) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in ./venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.0->langserve[all]) (0.1.52)
# Requirement already satisfied: packaging<24.0,>=23.2 in ./venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.0->langserve[all]) (23.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./venv/lib/python3.12/site-packages (from langchain-core<0.2.0,>=0.1.0->langserve[all]) (8.2.3)
# Requirement already satisfied: annotated-types>=0.4.0 in ./venv/lib/python3.12/site-packages (from pydantic>=1->langserve[all]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in ./venv/lib/python3.12/site-packages (from pydantic>=1->langserve[all]) (2.18.2)
# Collecting uvicorn (from sse-starlette<2.0.0,>=1.3.0->langserve[all])
#   Using cached uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jsonpointer>=1.9 in ./venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.0->langserve[all]) (2.4)
# Requirement already satisfied: requests<3,>=2 in ./venv/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.0->langserve[all]) (2.31.0)
# Collecting click>=7.0 (from uvicorn->sse-starlette<2.0.0,>=1.3.0->langserve[all])
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.0->langserve[all]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.12/site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2.0,>=0.1.0->langserve[all]) (2.2.1)
# Using cached fastapi-0.110.3-py3-none-any.whl (91 kB)
# Using cached httpx-0.27.0-py3-none-any.whl (75 kB)
# Using cached httpcore-1.0.5-py3-none-any.whl (77 kB)
# Using cached sse_starlette-1.8.2-py3-none-any.whl (8.9 kB)
# Using cached langserve-0.1.1-py3-none-any.whl (1.2 MB)
# Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Using cached anyio-4.3.0-py3-none-any.whl (85 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached uvicorn-0.29.0-py3-none-any.whl (60 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: sniffio, h11, click, uvicorn, httpcore, anyio, starlette, httpx, fastapi, sse-starlette, langserve
# Successfully installed anyio-4.3.0 click-8.1.7 fastapi-0.110.3 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 langserve-0.1.1 sniffio-1.3.1 sse-starlette-1.8.2 starlette-0.37.2 uvicorn-0.29.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama2:latest")

invoke = llm.invoke("Tell me a joke")
print(invoke)
# Out:
# Sure, here's one:
#
# Why don't scientists trust atoms?
# Because they make up everything!
